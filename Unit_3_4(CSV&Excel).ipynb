# %% [markdown]
# # CSV

# %%
import pandas as pd
df=pd.read_csv("Iris.csv")

# %% [markdown]
# ## Methods

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.fillna(0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## Attributes

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# # Excel

# %%
pip install xlrd==2.0.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1=pd.read_excel("Iris.xlsx")

# %%
df1
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
#Reading more than one sheet
df1=pd.read_excel("Iris.xlsx",sheet_name=0)
df2=pd.read_excel("Iris.xlsx",sheet_name=1)
print(df1)
print(df2)
# Out:
#      Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0             1          0.2           1.4          3.5           5.1
# 1             1          0.2           1.4          3.0           4.9
# 2             1          0.2           1.3          3.2           4.7
# 3             1          0.2           1.5          3.1           4.6
# 4             1          0.2           1.4          3.6           5.0
# ..          ...          ...           ...          ...           ...
# 145           3          2.3           5.2          3.0           6.7
# 146           3          1.9           5.0          2.5           6.3
# 147           3          2.0           5.2          3.0           6.5
# 148           3          2.3           5.4          3.4           6.2
# 149           3          1.8           5.1          3.0           5.9
#
#     Species_name
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
# ...

# %%
print(df1.head())
print(df2.tail())
# Out:
#    Species_No  Petal_width  Petal_length  Sepal_width  Sepal_length  \
# 0           1          0.2           1.4          3.5           5.1
# 1           1          0.2           1.4          3.0           4.9
# 2           1          0.2           1.3          3.2           4.7
# 3           1          0.2           1.5          3.1           4.6
# 4           1          0.2           1.4          3.6           5.0
#
#   Species_name
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
#    Unnamed: 0      Unnamed: 1
# 17        NaN             NaN
# 18        NaN             NaN
# 19        NaN             NaN
# 20        NaN             NaN
# 21        NaN  Iris Virginica

# %%
print("Sum: ",df1["Petal_width"].sum())
print("Mean: ",df1["Petal_width"].mean())
print("Max: ",df1["Petal_width"].max())
print("Min: ",df1["Petal_width"].min())
# Out:
# Sum:  179.90000000000003
# Mean:  1.1993333333333336
# Max:  2.5
# Min:  0.1

# %%
#skiprows
df3=pd.read_excel("Iris.xlsx", skiprows=5)
df3
# Out:
#      1  0.2  1.4  3.6    5      Setosa
# 0    1  0.4  1.7  3.9  5.4      Setosa
# 1    1  0.3  1.4  3.4  4.6      Setosa
# 2    1  0.2  1.5  3.4  5.0      Setosa
# 3    1  0.2  1.4  2.9  4.4      Setosa
# 4    1  0.1  1.5  3.1  4.9      Setosa
# ..  ..  ...  ...  ...  ...         ...
# 140  3  2.3  5.2  3.0  6.7   Verginica
# 141  3  1.9  5.0  2.5  6.3   Verginica
# 142  3  2.0  5.2  3.0  6.5   Verginica
# 143  3  2.3  5.4  3.4  6.2   Verginica
# 144  3  1.8  5.1  3.0  5.9   Verginica
#
# [145 rows x 6 columns]
